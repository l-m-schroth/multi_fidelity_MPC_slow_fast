# %% [markdown]
# Let's first try if the functionality works

# %%
from Differential_drive_MPC import DifferentialDriveMPC, DifferentialDriveMPCOptions
import gc
import numpy as np
import matplotlib.pyplot as plt
from utils_diff_drive import simulate_closed_loop
from plotting_utils_diff_drive import plot_diff_drive_trajectory
from utils_diff_drive import compute_exponential_step_sizes

# Compile MPC

# mpc_opts = DifferentialDriveMPCOptions()
# N = 100
# mpc_opts.N = N
# dt_inital_mpc = 0.05 # inital step size of 0.003 already fails!!!
# # mpc_opts.step_sizes = compute_exponential_step_sizes(
# #     dt_initial=0.01,
# #     T_total=20.0,
# #     N_steps=N,
# #     plot=True
# # ) #[dt_inital_mpc]*10000
# mpc_opts.step_sizes = [dt_inital_mpc]*N
# mpc_opts.switch_stage = 5000
# mpc_opts.integrator_type = "IRK"
# # mpc_opts.ellipse_centers = np.array([
# #         [-0.5, 0.3],  # Center of first ellipse
# #     ])
# # mpc_opts.ellipse_half_axes = np.array([
# #         [0.01, 0.01],   # Half-axis lengths (a, b) for first ellipse
# #     ])
# mpc = DifferentialDriveMPC(mpc_opts)

# print("Acados compiles sucessfully")

# # call solve for given initial state
# X0 = np.array([-1.0, 1.0, 0.0, -np.pi/2, 0.0, 0.0, 0.0])  #np.array([1.0, 0.0, 0.0, np.pi, 0.0, 0.0, 0.0])  # Intital state
# mpc.solve(X0)
# print("Solve runs through succesfully")

# # Visualize open loop plan
# traj_x, traj_u = mpc.get_planned_trajectory()
# print(traj_u)
# plot_diff_drive_trajectory(np.zeros(2), mpc=mpc, open_loop_plan=traj_x)

# # Try simulation in closed loop
# duration = 4.0
# if True:

#     mpc_opts_sim = DifferentialDriveMPCOptions()
#     mpc_opts_sim.N = 1
#     dt_sim = 0.01
#     mpc_opts_sim.step_sizes = [dt_sim]*1
#     mpc_opts_sim.switch_stage = 2
#     mpc_sim = DifferentialDriveMPC(mpc_opts_sim)
#     control_step = int(dt_inital_mpc/dt_sim)
#     print("control_step:", control_step)
#     x_traj, u_traj, stage_costs, solve_times = simulate_closed_loop(X0, mpc, duration, sim_solver=mpc_sim.acados_sim_solver, control_step=control_step)
#     print("Closed loop sim runs through succesfully")

#     plot_diff_drive_trajectory(np.zeros(2), mpc=mpc, closed_loop_traj=x_traj)

#     print("mean solve time:", np.mean(solve_times))
#     print("mean costs:", np.mean(stage_costs))

#     x_traj = np.array(x_traj)
#     u_traj = np.array(u_traj)

#     time_x = np.arange(x_traj.shape[0]) * control_step
#     time_u = np.arange(u_traj.shape[0]) * control_step

#     nx = x_traj.shape[1]
#     nu = u_traj.shape[1]

#     # Plot states
#     plt.figure(figsize=(12, 6))
#     for i in range(nx):
#         plt.plot(time_x, x_traj[:, i], label=f"$x_{i}$")
#     plt.xlabel("Time [s]")
#     plt.ylabel("States")
#     plt.title("State Trajectory Over Time")
#     plt.grid(True)
#     plt.legend()
#     plt.tight_layout()
#     plt.show()

#     # Plot controls
#     plt.figure(figsize=(10, 4))
#     for i in range(nu):
#         plt.step(time_u, u_traj[:, i], where='post', label=f"$u_{i}$")
#     plt.xlabel("Time [s]")
#     plt.ylabel("Control Inputs")
#     plt.title("Control Inputs Over Time")
#     plt.grid(True)
#     plt.legend()
#     plt.tight_layout()
#     plt.show()

# del mpc
# del mpc_sim
# gc.collect()

# %% [markdown]
# For our experiment, we compare the following MPCs. As ground truth model we consider the model integrated with step size 0.005. Consistently, we simulate at 200Hz and apply the MPCs with a frequency (zero order hold) corresponding to their initial step size.
#
# 0) Baseline: Naive Long Horizon MPC, step size is 0.01 and we have an enormous horizon length of 1000. Thus, the MPC's planning horizon captures half of the entire 20s simulation. The MPC reaches a state very close to the goal state and achieves small costs.
#
# 1) Exact-model MPC with a larger initial step size of 0.02 and a horizon of 1000 (again overlooking half the simulaiton horizon). The MPC does not work at all, and the solver frequently fails. My understanding: The larger step size is too large and the dynamics of the MPC do not accurately capture the ground truth system anymore.
#
# 2) Exactly as 0), but integrated with ERK. We get solver errors. My understanding: ERK cannot handle the stiff dynamics.
#
# 3) Exact-model MPC with initial step size of 0.002 and a shorter time horizon of 250. The shorter horizon leads to worse performance in terms of costs and a deviation from the goal state. This effect increases when further decreasing the horizon length.
#
# 4) Exact-model MPC with exponential increase of step size at an sensible rate. We choose 100 stages. The time horizon is still 20s to achieve a far lookahead distance.
#
# 5) Our approach: Combining exponential increase of step size with model switching after stage 20. Neglecting the fast actuator dynamics, we not only reduce the dimension of the state but can switch to ERK for the second part of the horizon, which is much cheaper than using the implicit IRK.

# %%
import gc
import shutil

# initialize sim solver for closed loop simulation, we also use the DifferentialDrive MPC class to instatiate the sim solver.
mpc_opts_sim = DifferentialDriveMPCOptions()
mpc_opts_sim.N = 1
dt_sim = 0.005
mpc_opts_sim.step_sizes = [dt_sim]*1
mpc_opts_sim.switch_stage = 2
mpc_sim = DifferentialDriveMPC(mpc_opts_sim)
sim_solver = mpc_sim.acados_sim_solver

# MPC config shared by all MPCs 
dt_inital_mpc = 0.01
control_step = int(dt_inital_mpc/dt_sim) # determines zero order hold of the MPC
X0 = np.array([-1.0, 1.0, 0.0, -np.pi/2, 0.0, 0.0, 0.0])
duration = 15.0

# collect mean costs and solve times
mean_costs = []
mean_solve_times = []

del mpc_sim
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### 0) Baseline ###
mpc_opts_baseline = DifferentialDriveMPCOptions()
N = 1000
mpc_opts_baseline.N = N
mpc_opts_baseline.step_sizes = [dt_inital_mpc]*N
mpc_opts_baseline.switch_stage = N+1
mpc_opts_baseline.integrator_type = "IRK"
mpc_baseline = DifferentialDriveMPC(mpc_opts_baseline)

x_traj_0, u_traj_0, stage_costs, solve_times = simulate_closed_loop(X0, mpc_baseline, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_baseline, closed_loop_traj=x_traj_0)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_baseline
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### 1) Myopic Exact model MPC ###
mpc_opts_1 = DifferentialDriveMPCOptions()
N = 250
mpc_opts_1.N = N
mpc_opts_1.step_sizes = [dt_inital_mpc]*N
mpc_opts_1.switch_stage = N+1
mpc_opts_1.integrator_type = "IRK"
mpc_1 = DifferentialDriveMPC(mpc_opts_1)

x_traj_1, u_traj_1, stage_costs, solve_times = simulate_closed_loop(X0, mpc_1, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_1, closed_loop_traj=x_traj_1)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_1
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### 2) Larger step size ###
mpc_opts_2 = DifferentialDriveMPCOptions()
N = 250
mpc_opts_2.N = N
mpc_opts_2.step_sizes = [4*dt_inital_mpc]*N
mpc_opts_2.switch_stage = N+1
mpc_opts_2.integrator_type = "IRK"
mpc_2 = DifferentialDriveMPC(mpc_opts_2)

x_traj_1, u_traj_1, stage_costs, solve_times = simulate_closed_loop(X0, mpc_2, duration, sim_solver=sim_solver, control_step=2*control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_2, closed_loop_traj=x_traj_1)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_2
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### ERK usage ###
mpc_opts_ERK = DifferentialDriveMPCOptions()
N = 1000
mpc_opts_ERK.N = N
mpc_opts_ERK.step_sizes = [dt_inital_mpc]*N
mpc_opts_ERK.switch_stage = N+1
mpc_opts_ERK.integrator_type = "ERK"
mpc_ERK = DifferentialDriveMPC(mpc_opts_ERK)

x_traj_ERK, u_traj_ERK, stage_costs, solve_times = simulate_closed_loop(X0, mpc_ERK, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_ERK, closed_loop_traj=x_traj_ERK)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_ERK
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_ode_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_forw.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_expl_vde_adj.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 2, QP iteration 41.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 44.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 40.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 39.
#
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 78.
#
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 23.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 8.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 9.
# [VanDerPolMPC] OCP solver returned status 4.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 10.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 11.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 14.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 18.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 18.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 18.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 12.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 17.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 13.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 16.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 15.
# ...
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 54.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 46.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 46.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 47.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 54.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 54.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 48.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 48.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 45.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 55.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 48.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 46.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 46.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 50.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 49.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 52.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 51.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 47.
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 46.
# [VanDerPolMPC] OCP solver returned status 4.
# QP solver returned error status 3 in SQP iteration 1, QP iteration 47.
#
# [VanDerPolMPC] OCP solver returned status 4.
#
# QP solver returned error status 3 in SQP iteration 1, QP iteration 53.

# %%
### 4) Exponential increase in stepsize ###
mpc_opts_4 = DifferentialDriveMPCOptions()
N = 80
mpc_opts_4.N = N
mpc_opts_4.step_sizes = compute_exponential_step_sizes(
    dt_initial=dt_inital_mpc,
    T_total=10,
    N_steps=N,
    plot=False
)
mpc_opts_4.switch_stage = N+1
mpc_opts_4.integrator_type = "IRK"
mpc_4 = DifferentialDriveMPC(mpc_opts_4)

x_traj_4, u_traj_4, stage_costs, solve_times = simulate_closed_loop(X0, mpc_4, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_4, closed_loop_traj=x_traj_4)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_4
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### 5) Model switching ###
mpc_opts_5 = DifferentialDriveMPCOptions()
N = 1000
mpc_opts_5.N = N
mpc_opts_5.step_sizes = [dt_inital_mpc]*N
mpc_opts_5.switch_stage = N+1
mpc_opts_5.integrator_type = "IRK"
mpc_5 = DifferentialDriveMPC(mpc_opts_5)

x_traj_5, u_traj_5, stage_costs, solve_times = simulate_closed_loop(X0, mpc_5, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_5, closed_loop_traj=x_traj_0)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_5
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rm -f libacados_ocp_solver_actuators_diff_drive_with_actuators.so
# rm -f acados_solver_actuators_diff_drive_with_actuators.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_actuators_diff_drive_with_actuators.o acados_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_ocp_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
### 6) Ours Mixed model, exponential step size increase ###
mpc_opts_6 = DifferentialDriveMPCOptions()
N = 80
mpc_opts_6.N = N
mpc_opts_6.step_sizes = compute_exponential_step_sizes(
    dt_initial=dt_inital_mpc,
    T_total=10,
    N_steps=N,
    plot=False
)
mpc_opts_6.switch_stage = 20 # only keep actuator model in first part of the horizon
mpc_opts_6.integrator_type = "IRK" # switch to ERK happens automatically in the class
mpc_6 = DifferentialDriveMPC(mpc_opts_6)

x_traj_6, u_traj_6, stage_costs, solve_times = simulate_closed_loop(X0, mpc_6, duration, sim_solver=sim_solver, control_step=control_step)
plot_diff_drive_trajectory(np.zeros(2), mpc=mpc_6, closed_loop_traj=x_traj_6)
mean_costs.append(np.mean(stage_costs))
mean_solve_times.append(np.mean(solve_times))

del mpc_6
gc.collect()
shutil.rmtree('c_generated_code', ignore_errors=True)
# Out:
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# WARNING: set_phase: Phase 0 contains non-default solver options: ['N_horizon', 'integrator_type', 'levenberg_marquardt', 'nlp_solver_max_iter', 'qp_solver_iter_max', 'qp_solver_tol_comp', 'qp_solver_tol_eq', 'qp_solver_tol_ineq', 'qp_solver_tol_stat', 'sim_method_num_stages', 'tf'], which will be ignored.
#  Solver options need to be set via AcadosMultiphaseOcp.solver_options or mocp_opts instead.
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# WARNING: set_phase: Phase 2 contains non-default solver options: ['N_horizon', 'integrator_type', 'levenberg_marquardt', 'nlp_solver_max_iter', 'qp_solver_iter_max', 'qp_solver_tol_comp', 'qp_solver_tol_eq', 'qp_solver_tol_ineq', 'qp_solver_tol_stat', 'sim_method_num_stages'], which will be ignored.
#  Solver options need to be set via AcadosMultiphaseOcp.solver_options or mocp_opts instead.
# Phase 0 contains non-default terminal fields: ['Vx_e', 'W_e', 'yref_e'], which will be ignored.
# Calling make_consistent for phase 0.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Calling make_consistent for phase 1.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Phase 2 contains non-default initial fields: ['idxbx_0', 'idxbxe_0', 'lbx_0', 'ubx_0'], which will be ignored.
# Calling make_consistent for phase 2.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# rendered model templates successfully
#
# mocp_render_templates: rendered solver templates successfully!
#
# rm -f libacados_ocp_solver_multiphase_ocp_20_1_60_20250404_225405_174290.so
# rm -f transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun.o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun_jac_ut_xt.o acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun.o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun_jac_ut_xt.o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.o acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.c
# acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.c: In function ‘multiphase_ocp_20_1_60_20250404_225405_174290_acados_create_with_discretization’:
# acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.c:1694:25: warning: too many arguments for format [-Wformat-extra-args]
#  1694 |         fprintf(stderr, "multiphase_ocp_20_1_60_20250404_225405_174290_acados_create_with_discretization: new_time_steps should be NULL " \
#       |                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun.o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun_jac.o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun_jac.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_expl_ode_fun.o diff_drive_model/diff_drive_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_expl_vde_forw.o diff_drive_model/diff_drive_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_expl_vde_adj.o diff_drive_model/diff_drive_expl_vde_adj.c
# cc -shared transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun.o transition_actuators_to_diff_drive_cost/transition_actuators_to_diff_drive_cost_y_fun_jac_ut_xt.o acados_solver_multiphase_ocp_20_1_60_20250404_225405_174290.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun.o transition_actuators_to_diff_drive_model/transition_actuators_to_diff_drive_dyn_disc_phi_fun_jac.o diff_drive_model/diff_drive_expl_ode_fun.o diff_drive_model/diff_drive_expl_vde_forw.o diff_drive_model/diff_drive_expl_vde_adj.o -o libacados_ocp_solver_multiphase_ocp_20_1_60_20250404_225405_174290.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_actuators_diff_drive_with_actuators.o acados_sim_solver_actuators_diff_drive_with_actuators.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_actuators_diff_drive_with_actuators.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u_z.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_fun_jac_x_xdot_u.o actuators_diff_drive_with_actuators_model/actuators_diff_drive_with_actuators_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_actuators_diff_drive_with_actuators.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_diff_drive.o acados_sim_solver_diff_drive.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_diff_drive.o diff_drive_model/diff_drive_impl_dae_fun.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u_z.o diff_drive_model/diff_drive_impl_dae_fun_jac_x_xdot_u.o diff_drive_model/diff_drive_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_diff_drive.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
from plotting_utils_diff_drive import plot_closed_loop_trajectories_and_inputs

initial_state_filter = np.vstack([X0[0], X0[1], X0[3]])
goal_state = np.zeros(3)

plot_closed_loop_trajectories_and_inputs(
    x_traj_0, u_traj_0,
    x_traj_1, x_traj_1,
    x_traj_6, x_traj_6,
    dt_sim,
    initial_state_filter,
    goal_state,
    latexify=True,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from plotting_utils_diff_drive import plot_closed_loop_trajectories_and_inputs
#       3 initial_state_filter = np.vstack([X0[0], X0[1], X0[3]])
#       4 goal_state = np.zeros(3)
#
# ImportError: cannot import name 'plot_closed_loop_trajectories_and_inputs' from 'plotting_utils_diff_drive' (/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/multi_fidelity_MPC_fast_slow/diff_drive/plotting_utils_diff_drive.py)

# %%
# Plot as bar diagrams the mean costs and mean computation times of the different approaches
# X-axis labels for the bars
labels = [0, 1, 2, 3, 4, 5]

# Plot 1: Mean Stage Costs
plt.figure(figsize=(8, 4))
plt.bar(labels, mean_costs)
plt.axhline(y=mean_costs[0], color='red', linestyle='--', linewidth=2, label='Baseline')
plt.xlabel("Approach")
plt.ylabel("Mean Stage Cost")
plt.title("Mean Stage Cost per Approach")
plt.xticks(labels)
plt.ylim(4500, 5500)
#plt.yscale('log') 
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# Plot 2: Mean Computation Time
plt.figure(figsize=(8, 4))
plt.bar(labels, mean_solve_times)
plt.xlabel("Approach")
plt.ylabel("Mean Solve Time [s]")
plt.title("Mean Computation Time per Approach")
plt.xticks(labels)
plt.grid(True, axis='y')
plt.yscale('log') 
plt.tight_layout()
plt.show()

# %%
print(mean_costs)
print(mean_solve_times)
# Out:
# [4705.447945366376, 4736.78887603587, 404732.7114288126, 4955.323000879781, 4889.278958490963, 4705.7535912679905]
# [0.2138913446666667, 0.06592597866666668, 0.07753279266666667, 0.027762225333333328, 0.019570780666666666, 0.013802949333333333]
